# %% [markdown]
# Exercicio com IF

# %% [markdown]
# 2.Calculo de bonus com uma nova regra.

# %%
vendas_funcionario1 = 1000
vendas_funcionario2 = 770
vendas_funcionario3 = 2700

if vendas_funcionario1 >= 1000:
    print('Ofuncionario 1 ganhou {} de bonus'.format(vendas_funcionario1 * 0.1))

if  vendas_funcionario2 >= 1000:
    bonus = vendas_funcionario2 * 0.1

else:
    bonus = 0 
    print('O Funcionario 2 ganhou {} de bonus' .format(bonus))

if  vendas_funcionario3 >= 1000:
    bonus = vendas_funcionario3 * 0.1

else:
  
    bonus = 0 
print('O Funcionario 3 ganhou {} de bonus' .format(bonus))
# Out:
# Ofuncionario 1 ganhou 100.0 de bonus
# O Funcionario 2 ganhou 0 de bonus
# O Funcionario 3 ganhou 270.0 de bonus

# %%
idade=input('Qual sua idade? ')
nome=input('Qual seu nome? ')
escola=input('Qual o nome da sua escola? ')
esporte=input('Voce pratica algum esporte? ')
animal=input('Qual o seu animal de estimação? ')

# %%
notas={'joao':9,'maria':10,'zezinho':4}
type(notas)
# Out:
# dict

# %%
lista=['gato', 'rato', 'elefante']
type(lista)
# Out:
# list

# %%
n=[ 9.5 , 10.0 , 7.4]
type(n)
# Out:
# list

# %%
nome   = input("Qual seu nome: ")
idade  = int(input("Qual sua idade: "))
altura = float(input("Qual sua altura: "))
peso   = float(input("Qual seu peso:"))
op     = int(input("Estado civil:\n1.Casado\n2.Solteiro\n"))

if op==1:
  op = True

else:
  op = False

eu = [nome, idade, altura, peso, op]
print(eu)
print("Nome : ", eu[0])
print("Idade : ", eu[1], " anos")
print("Altura: ", eu[2], "m")
print("Peso : ", eu[3], "kg")
print("Casado: ", eu[4])
# Out:
# Qual seu nome: daniel
# Qual sua idade: 38
# Qual sua altura: 179
# Qual seu peso:114
# Estado civil:
# 1.Casado
# 2.Solteiro
# 1
# ['daniel', 38, 179.0, 114.0, True]
# Nome :  daniel
# Idade :  38  anos
# Altura:  179.0 m
# Peso :  114.0 kg
# Casado:  True

# %% [markdown]
# Estudo IF e ELSE.

# %%
idade=int(input('Idade: '))
if idade>17 :
  print('Você é de maior, já pode dirigir!')
# Out:
# Idade: 18
# Você é de maior, já pode dirigir!

# %%
meta   =   20000
vendas = 500000

if vendas < meta:
    print('Não ganhou bónus')
elif vendas > (meta * 2):
      bonus = 0.07 *vendas
      print('Ganhou {} de bónus'.format(bonus))
else:
    bonus = 0.03 * vendas
    print('Ganhou {} de bónus'.format(bonus))
# Out:
# Ganhou 35000.0 de bónus

# %%
faturamento_loja_1 = 25000
faturamento_loja_2 = 25000
email = 'daniel@gmail.com'

print('Programa 1')
if faturamento_loja_1 == faturamento_loja_2:
    print('Os faturamentos são iguais')
else:
    print('Os faturamentos são diferentes')
# Out:
# Programa 1
# Os faturamentos são iguais

# %%
print('Porgrama 2')
if email == 'daniel@gmail.com.br':
    print('Email correto')
else:
    print('Email errado')
# Out:
# Porgrama 2
# Email errado

# %%
print('Programa 2')
email_usuario = input('Insira seu email:')
if not '@' in email_usuario:
  print('Email Invalido')
else:
    pass
# Out:
# Programa 2
# Insira seu email:daniel.com.br
# Email Invalido

# %%
sexo = int( input('Digite 1 se for mulher, 2 homem ou 3 outro: ') )
if sexo == 1:
  print('Você é mulher')
if sexo == 2:
  print('Vocè é homem')
if sexo == 3:
  print('Outro gênero')
# Out:
# Digite 1 se for mulher, 2 homem ou 3 outro: 2
# Vocè é homem

# %%
lista10 = ['Agua','Açucar','Arroz','Pão','Leite','Massa','Carne','Refrigerante']

for i in lista10:
  print( i, end=','),
# Out:
# Agua,Açucar,Arroz,Pão,Leite,Massa,Carne,Refrigerante,

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo
 
print('O Faturamento da loja foi, {}. O Custo da loja foi, {}. Assim,o Lucro da Loja foi'.format(faturamento,custo,lucro,))
# Out:
# O Faturamento da loja foi, 2000. O Custo da loja foi, 500. Assim,o Lucro da Loja foi

# %%
meta = 50000
qtde_vendida = 40000
if qtde_vendida > meta:
   print('Batemos da Meta de vendas de Iphone,vendemos {} unidades'.format(qtde_vendida))
else:
   print('Infelizmente Não batemos a Meta, vendemos {} unidades. A meta era de {} unidades'.format(qtde_vendida, meta))
# Out:
# Infelizmente Não batemos a Meta, vendemos 40000 unidades. A meta era de 50000 unidades

# %%
meta = 5000
qtde_vendida = 65300
  print('Batemos a meta de vendas de iphone,vendemos {} unidades'.format(qtde_vendida))
